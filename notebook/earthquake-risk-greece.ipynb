# %% [markdown]
# # Earthquake risk in Greece
#
# This project is quite different from a software development task.
#
# Don't hesitate to contact us, if you have any doubts on what is asked or if you encounter error will using the notebook.

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Constraints
#
# + 🚨 Only cells with the comment `# NOTE: Fill me!` should be filled
# + 🚨 Notebook should be saved and commited **with** outputs for the submission
#
#
# + ⚠️ The solution only requires packages listed in the `requirements/requirements.txt`
# + ⚠️ Unit tests should be favored when asked to write tests
# + ⚠️ Tests must automatically be detected running `pytest`
# + ⚠️ Requested method signature should be inferred from this notebook
#
#
# ## Note
#
# + The `assert` statements in the notebook are here to guide the project.
# However, successful `assert` statements does not guaranty that your code is correct.
#
# ## Setup
#
# In a Python >= 3.8 virtual env, run:

# %%
! pip install -r ../requirements/requirements.txt
! pip install --no-deps -e ..
# Out:
# Requirement already satisfied: pandas in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from -r ../requirements/requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: numpy in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from -r ../requirements/requirements.txt (line 2)) (1.21.5)
# Requirement already satisfied: ipykernel in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from -r ../requirements/requirements.txt (line 3)) (6.15.2)
# Requirement already satisfied: pytest in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from -r ../requirements/requirements.txt (line 4)) (7.1.2)
# Requirement already satisfied: matplotlib in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from -r ../requirements/requirements.txt (line 5)) (3.5.2)
# Requirement already satisfied: asyncio in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from -r ../requirements/requirements.txt (line 6)) (3.4.3)
# Requirement already satisfied: aiohttp in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from -r ../requirements/requirements.txt (line 7)) (3.8.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r ../requirements/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from pandas->-r ../requirements/requirements.txt (line 1)) (2022.1)
# Requirement already satisfied: tornado>=6.1 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (6.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (1.5.5)
# Requirement already satisfied: pyzmq>=17 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (23.2.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (7.3.4)
# Requirement already satisfied: debugpy>=1.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (1.5.1)
# Requirement already satisfied: packaging in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (21.3)
# Requirement already satisfied: traitlets>=5.1.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (7.31.1)
# Requirement already satisfied: psutil in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (5.9.0)
# Requirement already satisfied: appnope in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipykernel->-r ../requirements/requirements.txt (line 3)) (0.1.2)
# Requirement already satisfied: attrs>=19.2.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from pytest->-r ../requirements/requirements.txt (line 4)) (21.4.0)
# Requirement already satisfied: iniconfig in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from pytest->-r ../requirements/requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from pytest->-r ../requirements/requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: py>=1.8.2 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from pytest->-r ../requirements/requirements.txt (line 4)) (1.11.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from pytest->-r ../requirements/requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->-r ../requirements/requirements.txt (line 5)) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->-r ../requirements/requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->-r ../requirements/requirements.txt (line 5)) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->-r ../requirements/requirements.txt (line 5)) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->-r ../requirements/requirements.txt (line 5)) (0.11.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->-r ../requirements/requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->-r ../requirements/requirements.txt (line 7)) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->-r ../requirements/requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->-r ../requirements/requirements.txt (line 7)) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->-r ../requirements/requirements.txt (line 7)) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from aiohttp->-r ../requirements/requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: setuptools>=18.5 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (63.4.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (3.0.20)
# Requirement already satisfied: decorator in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.7.5)
# Requirement already satisfied: backcall in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.2.0)
# Requirement already satisfied: pygments in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.18.1)
# Requirement already satisfied: entrypoints in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel->-r ../requirements/requirements.txt (line 3)) (4.11.1)
# Requirement already satisfied: six>=1.5 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas->-r ../requirements/requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: idna>=2.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from yarl<2.0,>=1.0->aiohttp->-r ../requirements/requirements.txt (line 7)) (3.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/mathieulamiot/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->-r ../requirements/requirements.txt (line 3)) (0.2.5)
# Obtaining file:///Users/mathieulamiot/Documents/Perso/GitHub/descartes-soft-eng
#   Preparing metadata (setup.py) ... done
# Installing collected packages: earthquakes
#   Attempting uninstall: earthquakes
#     Found existing installation: earthquakes dev
#     Uninstalling earthquakes-dev:
#       Successfully uninstalled earthquakes-dev
#   Running setup.py develop for earthquakes
# Successfully installed earthquakes-dev

# %% [markdown]
# ## Tests

# %%
! cd .. && pytest
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.9.13, pytest-7.1.2, pluggy-1.0.0
# rootdir: /Users/mathieulamiot/Documents/Perso/GitHub/descartes-soft-eng
# plugins: anyio-3.5.0
# collected 21 items
#
# tests/src/earthquakes/test_tools.py ......                               [ 28%]
# tests/src/earthquakes/test_usgs_api.py ...............                   [100%]
#
# ============================== 21 passed in 0.72s ==============================

# %% [markdown]
# ---

# %% [markdown]
# # Context
#
# A client asks for an insurance of their asset, located at `(35.025, 25.763)` in Greece.
#
# The client wishes to receive a payout under the following conditions:
#
# + earthquake of magnitude `4.5` or higher within `10km`: full payout
# + earthquake of magnitude `5.5` or higher within `50km`: `75%` payout
# + earthquake of magnitude `6.5` or higher within `200km`: `50%` payout
#
# In the event of aftershocks, a payout can only occur once a year using the maximal value.
#
# ## Example
#
# If in the same year:
#
# * an earthquake of magnitude `6.8` occurs within `200km`
# * **and** an aftershock of magnitude `5.8` occurs within `50km`
#
# the client receives a `75%` payout, and not a `125%` payout.

# %%
import numpy as np
import pandas as pd
from datetime import datetime

from earthquakes.tools import (
    DISTANCE_COLUMN,
    LATITUDE_COLUMN,
    LONGITUDE_COLUMN,
)

# %% [markdown]
# # Earthquake data
#
# The US Geological Service (USGS) provides CSV data through their [API](https://earthquake.usgs.gov/fdsnws/event/1/).
#
# Use it to retrieve earthquake information.
#
# In the module `earthquakes.usgs_api`:
# + Implement the function `get_earthquake_data`,
# + The function will retrieve the earthquake data of the area of interest for the past 200 years,
# + The implementation must use the `urllib` python package,
# + The API request url must be build in a dedicated function `build_api_url`,
# + Tests should be provided for `build_api_url`.
#
# Note: Earthquakes after the 21-10-2021 should not be considered.

# %%
from earthquakes.usgs_api import get_earthquake_data

# %%
# NOTE: Fill me!

latitude = 35.025
longitude = 25.763
radius = 200
minimum_magnitude = 4.5

# %%
# NOTE: This request may take significant time (>10s)
earthquake_data = get_earthquake_data(
    latitude=latitude,
    longitude=longitude,
    radius=radius,
    minimum_magnitude=minimum_magnitude,
    end_date=datetime(year=2021, month=10, day=21)
)

# %%
assert isinstance(earthquake_data, pd.DataFrame)
assert len(earthquake_data) == 734

# %% [markdown]
# ## Warning
#
# The next test may fail because USGS regularly updates their earthquake database.
#
# The dataframe obtained should over be similar to that presented bellow.
#
# Please contact us if there is an error.

# %%
expected_earthquake_data = pd.DataFrame([
        ["2021-10-12T09:24:05.099Z", 35.1691, 26.2152, 20.0, 6.4, "mww", np.nan, 19.0, 0.860, 0.46,"us", "us6000ftxu", "2021-12-18T19:58:57.040Z", "4 km SW of Palekastro, Greece", "earthquake", 6.1, 1.8, 0.048, 42.0, "reviewed", "us", "us"],
        ["2021-10-03T14:31:27.622Z", 35.1442, 25.2375, 10.0, 4.6, "mb", np.nan, 119.0, 0.318, 0.64, "us", "us6000fsp1", "2021-12-10T21:14:19.040Z", "2 km W of Arkalochóri, Greece", "earthquake", 5.0, 1.9, 0.165, 13.0, "reviewed", "us", "us"],
        ["2021-09-29T11:54:48.885Z", 35.0268, 25.1561, 10.0, 4.6, "mb", np.nan, 69.0, 0.339, 0.83, "us", "us6000fq3y", "2021-12-04T14:27:58.040Z", "2 km N of Pýrgos, Greece", "earthquake", 5.1, 1.3, 0.068, 64.0, "reviewed", "us", "us"],
        ["2021-09-28T15:13:16.867Z", 35.2054, 25.2791, 10.0, 4.7, "mb", np.nan, 58.0, 0.329, 0.70, "us", "us7000ff84", "2021-12-04T14:30:09.040Z", "1 km N of Thrapsanón, Greece", "earthquake", 6.9, 1.8, 0.067, 73.0, "reviewed", "us", "us"],
        ["2021-09-28T04:48:08.650Z", 35.0817, 25.2018, 10.0, 5.3, "mww", np.nan, 43.0, 0.328, 0.94, "us", "us7000ff36", "2021-12-04T14:30:04.040Z", "9 km SW of Arkalochóri, Greece", "earthquake", 4.5, 1.7, 0.046, 45.0, "reviewed", "us", "us"],
    ],
    columns=['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst', 'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type', 'horizontalError', 'depthError', 'magError', 'magNst', 'status', 'locationSource', 'magSource']
)

# %%
earthquake_data_sample = earthquake_data[
    earthquake_data["time"].isin(expected_earthquake_data["time"])
]

pd.testing.assert_frame_equal(earthquake_data_sample, expected_earthquake_data)

# %% [markdown]
# # Distance
#
# We wish to compute the the historical payouts (i.e. the payouts that would have occurred for the past 200 years).
#
# To compute the historical payouts, we need to know the distance between each earthquake and our client's asset.
#
# The distance between two points on a sphere is the [Haversine distance](https://en.wikipedia.org/wiki/Haversine_formula). In the module `eathquakes.tools`:
# - Implement and test the function `get_haversine_distance`,
# - Use `earthquakes.tools.EARTH_RADIUS` (6378km) as an approximation of the radius of Earth.

# %%
from earthquakes.tools import get_haversine_distance

distances = get_haversine_distance(earthquake_data[LATITUDE_COLUMN], earthquake_data[LONGITUDE_COLUMN], latitude, longitude)

earthquake_data[DISTANCE_COLUMN] = distances

# %% [markdown]
# ## Historical payouts and burning costs
#
# ### Payout
#
# The historical payouts are a map `year -> payout in %`.
#
# eg: `1950: 50` for a payout of `50%` in 1950.
#
# Payouts are NOT given per event, but per year.
#
# This map can take the form of a python `dict` or of a pandas `Series`.
#
# ### Burning cost
#
# The `burning cost` is the average of payouts over a time range.
#
# In this project, the burning cost should be expressed in `%`.
#
# ### Payout structure
#
# The payout structure is:
#
# | Radius | Magnitude | Payout |
# |--------|-----------|--------|
# | 10km   | 4.5       | 100 %  |
# | 50km   | 5.5       |  75 %  |
# | 200km  | 6.5       |  50 %  |
#
# Even though multiple events can happen in a given year, clients can only receive one payout.
#
# In the module `earthquakes.tools`:
# + Implement the functions `compute_payouts` and `compute_burning_cost`,
# + Tests for these functions are not required.
#
# ### Example
#
# A payout `{1950: 50, 1992: 75}` means that we would have paid our client
# + in 1950, for `50%` of the insured amount (called 'limit')
# + in 1992, for `75%` of the limit
#
# The burning cost over the `1922-2021` period would be `1.25%`.
#
# The burning cost over the `1972-2021` period would be `1.5%`.

# %%
from earthquakes.tools import compute_payouts, compute_burning_cost

# %%
# NOTE: Fill me!

payout_items = [[10, 4.5, 100], [50, 5.5, 75], [200, 6.5, 50]]

payout_structure = pd.DataFrame(payout_items, columns=['Radius', 'Magnitude', 'Payout'])

# %%
payouts = compute_payouts(earthquake_data, payout_structure)

# %%
# Depending on the return type of compute_payouts, the following line needs to be adjusted.
# - pd.Series:
#payout_values = np.array(payouts.values)
# - dict:
payout_values = np.array(list(payouts.values()))
assert np.max(payout_values) > 1
assert np.max(payout_values) <= 100

# %%
burning_cost = compute_burning_cost(payouts, start_year=1952, end_year=2021)

# %%
np.testing.assert_allclose(burning_cost, 10.71, atol=1e-2)

# %%
import matplotlib.pyplot as plt

# %%
years = range(1921, 2021)
plt.plot(
    years, 
    [
        compute_burning_cost(payouts, start_year=start_year, end_year=2021) 
        for start_year in years
    ]
)
plt.gca().invert_xaxis()

# %% [markdown]
# # Large asset portfolio - async requests
#
# Our client also whishes to cover a large amount of properties all over Europe.
#
# In order to speed-up the requests to the USGS API, in the module `earthquakes.usgs_api`:
# - Implement the `async` function `get_earthquake_data_for_multiple_locations`,
# - The implementation should use the `asyncio` and `aiohttp` libraries,
# - The solution should re-use some of the functions already written,
# - Tests are not required for any of the functions.
#
# Note: it is possible that the notebook autoreload feature doesn't work for `async` functions - a kernel restart may be necessary after each modifications.

# %%
import numpy as np
import pandas as pd
from datetime import datetime

from earthquakes.tools import (
    LATITUDE_COLUMN,
    LONGITUDE_COLUMN,
)

# %%
number_of_assets = 10
# NOTE: limiting to number of assets so that the query doesn't take too long.

# %%
random_state = np.random.RandomState(0)

random_values = random_state.random(2*number_of_assets)

latitudes = random_values[::2] * 20 + 35.0
longitudes = random_values[1::2] * 25 + 3.0

# %%
from earthquakes.usgs_api import get_earthquake_data_for_multiple_locations

# %%
# NOTE: Fill me!
assets = pd.DataFrame(list(zip(latitudes, longitudes)),
               columns =['latitude', 'longitude'])

# %%
# NOTE: This request may take significant time (>10s)
earthquake_data = await get_earthquake_data_for_multiple_locations(  # type: ignore
    assets, 
    radius=200, 
    minimum_magnitude=4.5, 
    end_date=datetime(year=2021, month=10, day=21)
)

# %%
assert isinstance(earthquake_data, pd.DataFrame)
assert len(earthquake_data) == 1151
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /var/folders/2h/rn1x6cpj5_v6k2v5l31722yc0000gp/T/ipykernel_23928/2410562632.py in <module>
#       1 assert isinstance(earthquake_data, pd.DataFrame)
# ----> 2 assert len(earthquake_data) == 1151
#
# AssertionError:

# %%
earthquake_data
# Out:
#                          time  latitude  longitude  depth   mag magType  \
# 0    2013-09-08T13:22:12.630Z   45.6097    22.8657   5.00  4.60      mb
# 1    2002-08-02T09:37:18.220Z   44.7110    21.6200  10.00  4.50      mb
# 2    2002-05-24T20:42:26.770Z   44.7610    21.6110  10.00  4.70      mb
# 3    1996-03-24T09:13:28.030Z   45.6230    21.0230  22.60  4.80      mb
# 4    1994-10-13T23:31:27.510Z   45.4930    21.0040  10.00  4.70      mb
# ..                        ...       ...        ...    ...   ...     ...
# 531  1908-06-23T14:41:31.410Z   36.7680    24.6970  15.00  5.52      mw
# 532  1908-06-23T14:14:13.520Z   36.6560    24.2240  15.00  5.45      mw
# 533  1908-05-17T12:30:50.780Z   34.9870    23.8840  35.00  6.06      mw
# 534  1906-06-17T01:13:17.920Z   34.5540    24.6620  15.00  5.34      mw
# 0    2021-09-23T03:17:58.019Z   48.9703    25.9793  15.84  4.50      mb
#
#        nst   gap   dmin   rms  ...                   updated  \
# 0      NaN   NaN    NaN  0.75  ...  2022-07-25T21:49:02.307Z
# 1    133.0   NaN    NaN  1.12  ...  2014-11-07T01:16:11.310Z
# 2    227.0   NaN    NaN  1.21  ...  2020-09-18T18:53:16.032Z
# 3      NaN   NaN    NaN  1.10  ...  2014-11-07T01:00:08.274Z
# 4      NaN   NaN    NaN  1.20  ...  2014-11-07T00:56:31.006Z
# ..     ...   ...    ...   ...  ...                       ...
# 531    NaN   NaN    NaN   NaN  ...  2022-05-09T15:20:45.492Z
# 532    NaN   NaN    NaN   NaN  ...  2022-05-09T15:20:39.941Z
# 533    NaN   NaN    NaN   NaN  ...  2022-04-25T20:29:39.549Z
# 534    NaN   NaN    NaN   NaN  ...  2022-05-09T15:24:32.393Z
# 0      NaN  42.0  1.425  0.98  ...  2021-12-03T15:01:52.040Z
#
#                                       place        type horizontalError  \
# 0    1 km WSW of General Berthelot, Romania  earthquake             NaN
# 1          4 km SW of Moldova Nou?, Romania  earthquake             NaN
# 2             2 km ESE of Pojejena, Romania  earthquake             NaN
# 3             3 km NW of Peciu Nou, Romania  earthquake             NaN
# 4              6 km SSE of Giulv?z, Romania  earthquake             NaN
# ..                                      ...         ...             ...
# 531            11 km ESE of Kímolos, Greece  earthquake             NaN
# 532              20 km WSW of Mílos, Greece  earthquake             NaN
# 533              25 km NW of Kastrí, Greece  earthquake             NaN
# 534              58 km S of Tympáki, Greece  earthquake             NaN
# 0             9 km ESE of Zavodske, Ukraine  earthquake             3.7
#
#     depthError  magError  magNst    status  locationSource  magSource
# 0          4.7     0.137     NaN  reviewed          us_buc         us
# 1          NaN       NaN    11.0  reviewed              us         us
# 2          NaN       NaN    66.0  reviewed              us         us
# 3          9.0       NaN     2.0  reviewed              us         us
# 4          NaN       NaN     4.0  reviewed              us         us
# ..         ...       ...     ...       ...             ...        ...
# 531        6.7     0.270     NaN  reviewed       iscgemsup  iscgemsup
# 532       35.5     0.230     NaN  reviewed       iscgemsup  iscgemsup
# 533       12.4     0.340     NaN  reviewed          iscgem     iscgem
# 534       15.9     0.200     NaN  reviewed       iscgemsup  iscgemsup
# 0          4.1     0.111    25.0  reviewed              us         us
#
# [1158 rows x 22 columns]
